# %% [markdown]
# # Calculating Polyspectra from a Simulation in Realtime
#
# After defining a system (e.g. a single quantum dot measured by a quantum point contact) we can start a simulation
# and watch the polyspectra being calculated in real time. The resulting spectra will be equivalent to the ones calculated
# directly from the stochastic master equation.

# %%
import QuantumPolyspectra as qp
from qutip import *
import numpy as np

# %%
# ------ Operators and Hamiltonian -----
dot_levels = 2
a = destroy(dot_levels)
n = a.dag() * a
rho_0 = ket2dm(basis(dot_levels, 0)) + ket2dm(basis(dot_levels, 1)) 
rho_0 /= np.trace(rho_0)
H = 0 * n

# ------ System Parameters ------
beta = 5
gamma_out = 0.5
gamma_in = 0.5

c_measure_strength = {
    'a': gamma_out**0.5,
    'a_d': gamma_in**0.5,
}

sc_measure_strength = {
    'n': beta
}

c_ops = {
    'a': a,
    'a_d': a.dag(),
}

sc_ops =  {
    'n': n,
}

e_ops = {
    'n': n,
}

system = qp.System(H, rho_0, c_ops, sc_ops, e_ops, c_measure_strength, sc_measure_strength)

# %% [markdown]
# Before starting the simulation we have to define a few parameters for the integration stochastic master equation
# and the fourier transform:

# %%
f_max = 2 #[kHz]
t_start = 0
t_stop = int(10e1)
n_steps = int(50e3+1)
t = np.linspace(t_start, t_stop, n_steps)
f_nyqist =  n_steps / t_stop / 2

print('f_ny: {:.3f} kHz'.format(f_nyqist))
print('f_min: {:.3f} kHz'.format(2 * f_nyqist / n_steps))
print('')
print('f_max: {} kHz'.format(f_max))
print('number of points: {}'.format(int(f_max // (2 * f_nyqist / n_steps))))
# Out:
# f_ny: 250.005 kHz
# f_min: 0.010 kHz
#
# f_max: 2 kHz
# number of points: 199

# %% [markdown]
# Now we just have to state the operate from which we want to analyze the corresponding measurement:

# %%
op = 'n'
title = 'Γ<sub>l</sub> = {:.2f} kHz, Γ<sub>r</sub> = {:.2f} kHz, β<sub>main</sub>= {:.1f} kHz<sup>0.5</sup>'.format(gamma_in, gamma_out, beta)
res = system.numeric_spec(t, op, f_max=f_max, power=1, order=2, max_samples=50, plot_after=25, solver_='milstein', title_in=title, with_noise=True, roll=False)
# Out:
# 50001
# Total run time:   1.32s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.23s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.26s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.24s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.27s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.27s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.30s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.34s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
#
# Total run time:   1.30s
# chunk shape:  10000
# fs: None
# Maximum frequency: 250.0
# 41
# Number of points: 41
# HBox(children=(FloatProgress(value=0.0, max=25.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fb21efae0878> in <module>
#       1 op = 'n'
#       2 title = 'Γ<sub>l</sub> = {:.2f} kHz, Γ<sub>r</sub> = {:.2f} kHz, β<sub>main</sub>= {:.1f} kHz<sup>0.5</sup>'.format(gamma_in, gamma_out, beta)
# ----> 3 res = system.numeric_spec(t, op, backend='cpu', f_max=f_max, power=1, order=2, max_samples=50, plot_after=25, solver_='milstein', title_in=title, with_noise=True, roll=False)
#       4
#
# ~/opt/anaconda3/lib/python3.7/site-packages/QuantumPolyspectra/generation.py in numeric_spec(self, t_window_in, op, f_max, power, order, max_samples, m, solver_, plot_after, sum_cumulant, new_cumulant, title_in, with_noise, roll, plot_simulation, backend)
#     742             for i in tqdm_notebook(range(plot_after)):
#     743                 traces = [self.parallel_tranisent(None, op, t=t_window_in, _solver='milstein', _normalize=True,
# --> 744                                                   with_noise=with_noise)]
#     745
#     746                 for trace in traces:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/QuantumPolyspectra/generation.py in parallel_tranisent(self, seed, measure_op, t, _solver, with_noise, _nsubsteps, _normalize)
#     583                           c_ops=c_ops_m, sc_ops=sc_ops_m, e_ops={measure_op: self.e_ops[measure_op]}, noise=seed,
#     584                           solver=_solver, nsubsteps=_nsubsteps,
# --> 585                           normalize=_normalize)  # , progress_bar=progress_bar)
#     586
#     587         if with_noise:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/qutip/stochastic.py in smesolve(H, rho0, times, c_ops, sc_ops, e_ops, _safe_mode, args, **kwargs)
#     648     sso.solver_name = "smesolve_" + sso.solver
#     649
# --> 650     res = _sesolve_generic(sso, sso.options, sso.progress_bar)
#     651
#     652     if e_ops_dict:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/qutip/stochastic.py in _sesolve_generic(sso, options, progress_bar)
#    1300
#    1301     results = sso.map_func(task, list(range(sso.ntraj)),
# -> 1302                            task_args, task_kwargs, **map_kwargs)
#    1303     noise = []
#    1304     for result in results:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/qutip/parallel.py in serial_map(task, values, task_args, task_kwargs, **kwargs)
#     187     for n, value in enumerate(values):
#     188         progress_bar.update(n)
# --> 189         result = task(value, *task_args, **task_kwargs)
#     190         results.append(result)
#     191     progress_bar.finished()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/qutip/stochastic.py in _single_trajectory(i, sso)
#    1356     #ssolver.set_data(sso)
#    1357     ssolver.set_solver(sso)
# -> 1358     result = ssolver.cy_sesolve_single_trajectory(i)#, sso)
#    1359     return result
#    1360
#
# ~/opt/anaconda3/lib/python3.7/site-packages/qutip/cy/stochastic.pyx in qutip.cy.stochastic.StochasticSolver.cy_sesolve_single_trajectory()
#
# KeyboardInterrupt:

# %%
op = 'n'
title = 'Γ<sub>l</sub> = {:.2f} kHz, Γ<sub>r</sub> = {:.2f} kHz, β<sub>main</sub>= {:.1f} kHz<sup>0.5</sup>'.format(gamma_in, gamma_out, beta)
res = system.numeric_spec(t, op, f_max=f_max, power=1, order=2, max_samples=50, plot_after=25, solver_='milstein', title_in=title, with_noise=True, roll=False)
# Out:
# <div>
#
#
#             <div id="07a6c95f-2f44-4a60-b858-3619879c26d0" class="plotly-graph-div" style="height:600px; width:850px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07a6c95f-2f44-4a60-b858-3619879c26d0")) {
#                     Plotly.newPlot(
#                         '07a6c95f-2f44-4a60-b858-3619879c26d0',
#                         [{"type": "scatter", "x": [0.0, 0.0504999495000505, 0.100999899000101, 0.15149984850015152, 0.201999798000202, 0.2524997475002525, 0.30299969700030305, 0.35349964650035354, 0.403999596000404, 0.4544995455004545, 0.504999495000505, 0.5554994445005556, 0.6059993940006061, 0.6564993435006565, 0.7069992930007071, 0.7574992425007575, 0.807999192000808, 0.8584991415008586, 0.908999091000909, 0.9594990405009596, 1.00999899000101, 1.0604989395010607, 1.110998889001